# %%
import numpy as np
import matplotlib.pyplot as plt

output = [1.300027351436849e-07, 3.2213936527016237e-06, 3.743455112439985e-05, 0.00027155910508572673, 0.0013812668796184706, 
     0.00524654883620912, 0.01547916147324168, 0.036436582000360075, 0.06976620671678428, 0.11025458196900566, 
     0.14544949968165427, 0.16162612095129344, 0.15239552271840445, 0.12265872832530914, 0.08469025708112027, 
     0.05036567644808521, 0.02588359978362378, 0.007033466318542761, 6.3407895689712238e-03, 4.3407895689712238e-03, 
     1.7122383407895689e-04, 1.3897122384078956e-04, 2.340798789712238e-05, 4.3407895689712238e-06, 7.844270497461834e-07, 
     1.1277737614326909e-07, 1.396110154744804e-08, 1.48091591810237e-09, 1.337662407544274e-10, 1.0207595589792238e-11, 
     6.514372580841833e-13, 3.4320733241333017e-14, 1.4676540310622315e-15, 4.98037108286407e-17, 1.2999336940099265e-18, 
     2.4941913764114756e-20, 3.276550049032036e-22, 2.594459819844793e-24, 9.153455599379315e-27, 0.0]
print sum(output)
# Out:
# 1.0

# %%
pos = range(40)
for i in range(len(pos)) :
    pos[i] = pos[i] - 0.5
plt.title('Individual Probability Analysis')
plt.xlabel('# of cities')
plt.ylabel('Probability of snow')
plt.bar(pos, output, facecolor='blue')
plt.plot(output, marker='d', linestyle='--', color='r')
plt.grid(True)
plt.show()

# %%
a = [1.300027351436849e-07, 3.2213936527016237e-06, 3.743455112439985e-05, 0.00027155910508572673, 0.0013812668796184706, 
     0.00524654883620912, 0.01547916147324168, 0.036436582000360075, 0.06976620671678428, 0.11025458196900566, 
     0.14544949968165427, 0.16162612095129344, 0.15239552271840445, 0.12265872832530914, 0.08469025708112027, 
     0.05036567644808521, 0.02588359978362378, 0, 0, 0, 0, 0, 0, 0, 7.844270497461834e-07, 1.1277737614326909e-07, 
     1.396110154744804e-08, 1.48091591810237e-09, 1.337662407544274e-10, 1.0207595589792238e-11, 6.514372580841833e-13, 
     3.4320733241333017e-14, 1.4676540310622315e-15, 4.98037108286407e-17, 1.2999336940099265e-18, 2.4941913764114756e-20, 
     3.276550049032036e-22, 2.594459819844793e-24, 9.153455599379315e-27, 0.0]
print sum(a)
# Out:
# 0.981947010708

# %%
left = [1.0207595589792238e-02,  1.0207595589792238e-03,  1.0207595589792238e-03, 
     0.000866503372 , 1.9907595589792238e-03, 
     0.0207595589792238e-05, 5.0207595589792238e-06]
print sum(a) + sum(left)
# Out:
# 0.997058616702

# %%
0.00798634521354276-0.0009528789
# Out:
# 0.007033466313542761
